# %% [markdown]
# ## Read in the Data, Select Subset
#
# http://jmcauley.ucsd.edu/data/amazon/links.html

# %%
import pandas as pd
import gzip
import random
import numpy as np

import re

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

def dataSubsets(PDFrames, lower = 1.0, upper = 5.0, num_reviews = 50000, num_test = 10000):
    newDF_upper = PDFrames.loc[PDFrames['overall']>=upper]
    newDF_lower = PDFrames.loc[PDFrames['overall']<=lower]
    
    check1 = newDF_upper['overall'].count()
    #print(check1)
    check2 = newDF_lower['overall'].count()
    #print(check2)

    total_data = num_reviews + num_test
    #print(total_data)
    
    #Check that there is enough data in both postive and negative reviews
    if (check1>=total_data) & (check2>=total_data):
        newDF_upper_sub = newDF_upper.sample(n=total_data, replace=False, random_state=1043)
        newDF_upper_sub['sentiment'] = 1
        newDF_lower_sub = newDF_lower.sample(n=total_data, replace=False, random_state=1043)
        newDF_lower_sub['sentiment'] = 0
        newDF_train = pd.concat([newDF_upper_sub[:num_reviews],newDF_lower_sub[:num_reviews]]).sample(frac=1)
        newDF_test = pd.concat([newDF_upper_sub[-num_test:],newDF_lower_sub[-num_test:]]).sample(frac=1)
    
    #Elif check that there is enough data in positive reviews
    elif(check1>=total_data):
        newDF_lower = PDFrames.loc[PDFrames['overall']<=(lower+1.0)]
        check2 = newDF_lower['overall'].count()
        
        #Check that there is enough data if we make reviews 
        if(check2>=total_data):
            newDF_upper_sub = newDF_upper.sample(n=total_data, replace=False, random_state=1043)
            newDF_upper_sub['sentiment'] = 1
            newDF_lower_sub = newDF_lower.sample(n=total_data, replace=False, random_state=1043)
            newDF_lower_sub['sentiment'] = 0
            newDF_train = pd.concat([newDF_upper_sub[:num_reviews],newDF_lower_sub[:num_reviews]]).sample(frac=1)
            newDF_test = pd.concat([newDF_upper_sub[-num_test:],newDF_lower_sub[-num_test:]]).sample(frac=1)
        else:
            print(f'Not enough data...\nData for Upper = {check1}\nData for Lower = {check2}')
    
    #Elif check that there is enough data in negative reviews
    elif(check2>=total_data):
        newDF_upper = PDFrames.loc[PDFrames['overall']>=(upper-1.0)]
        check1 = newDF_upper['overall'].count()
        
        #See if adding 4.0 gives enough data
        if(check1>=total_data):
            newDF_upper_sub = newDF_upper.sample(n=total_data, replace=False, random_state=1043)
            newDF_upper_sub['sentiment'] = 1
            newDF_lower_sub = newDF_lower.sample(n=total_data, replace=False, random_state=1043)
            newDF_lower_sub['sentiment'] = 0
            newDF_train = pd.concat([newDF_upper_sub[:num_reviews],newDF_lower_sub[:num_reviews]]).sample(frac=1)
            newDF_test = pd.concat([newDF_upper_sub[-num_test:],newDF_lower_sub[-num_test:]]).sample(frac=1)
        else:
            print(f'Not enough data...\nData for Upper = {check1}\nData for Lower = {check2}')
    #Otherwise lets append data (4+, and 2 or 1) to see if there is enough data for our analysis
    else:
        newDF_upper = PDFrames.loc[PDFrames['overall']>=(upper-1.0)]
        check1 = newDF_upper['overall'].count()
        
        newDF_lower = PDFrames.loc[PDFrames['overall']<=(lower+1.0)]
        check2 = newDF_lower['overall'].count()
        
        if (check1>=total_data) & (check2>=total_data):
            newDF_upper_sub = newDF_upper.sample(n=total_data, replace=False, random_state=1043)
            newDF_upper_sub['sentiment'] = 1
            newDF_lower_sub = newDF_lower.sample(n=total_data, replace=False, random_state=1043)
            newDF_lower_sub['sentiment'] = 0
            newDF_train = pd.concat([newDF_upper_sub[:num_reviews],newDF_lower_sub[:num_reviews]]).sample(frac=1)
            newDF_test = pd.concat([newDF_upper_sub[-num_test:],newDF_lower_sub[-num_test:]]).sample(frac=1)
        
        else:
            print(f'Not enough data...\nData for Upper = {check1}\nData for Lower = {check2}')
    
    return newDF_train, newDF_test

def SaveData (trainDirectory, testDirectory, trainDF, testDF):
    export_csv1 = trainDF.to_csv(trainDirectory, index = None, header=True)
    export_csv2 = testDF.to_csv(testDirectory, index = None, header=True)

# %%
files = [#'reviews_Video_Games.json.gz', 
#          'reviews_Toys_and_Games.json.gz', 
#          'reviews_Sports_and_Outdoors.json.gz', 
#          'reviews_Movies_and_TV.json.gz',
#          'reviews_Kindle_Store.json.gz', 
#          'reviews_Home_and_Kitchen.json.gz',
#          'reviews_Health_and_Personal_Care.json.gz', 
#          'reviews_Electronics.json.gz',
#          'reviews_Clothing_Shoes_and_Jewelry.json.gz',
#          'reviews_Cell_Phones_and_Accessories.json.gz', 
#          'reviews_CDs_and_Vinyl.json.gz',
#          'reviews_Books.json.gz', 
#         'reviews_Amazon_Instant_Video_5.json.gz']
filesNames = [#'reviews_Video_Games', 
#               'reviews_Toys_and_Games',
#               'reviews_Sports_and_Outdoors', 
#               'reviews_Movies_and_TV',
#               'reviews_Kindle_Store', 
#               'reviews_Home_and_Kitchen',
#               'reviews_Health_and_Personal_Care', 
#               'reviews_Electronics',
#               'reviews_Clothing_Shoes_and_Jewelry',
#               'reviews_Cell_Phones_and_Accessories', 
#               'reviews_CDs_and_Vinyl',
#               'reviews_Books', 
#              'reviews_Amazon_Instant_Video_5']

# %%
random.seed(1027)
for fileName, writeName in zip(files, filesNames):
    print('_______________________________________________________')
    print('Working with %s'%(fileName))
    
    df = getDF('../Data/%s'%(fileName))
    print('Completed Parsing %s'%(fileName))
    
    train, test = dataSubsets(df)
    print('Completed Subsetting %s'%(fileName))
    
    SaveData(r'../CleanedData/%s_train.csv'%(writeName), 
         r'../CleanedData/%s_test.csv'%(writeName), 
         train, test)
    print('Wrote train and test data for %s\n\n'%(fileName))
# Out:
# _______________________________________________________
# Working with reviews_Amazon_Instant_Video_5.json.gz
# Completed Parsing reviews_Amazon_Instant_Video_5.json.gz
# Not enough data...
# Data for Upper = 29336
# Data for Lower = 3603
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-4e06dc2ed42b> in <module>()
#       7     print('Completed Parsing %s'%(fileName))
#       8
# ----> 9     train, test = dataSubsets(df)
#      10     print('Completed Subsetting %s'%(fileName))
#      11
#
# <ipython-input-3-f68596121b79> in dataSubsets(PDFrames, lower, upper, num_reviews, num_test)
#      83             print(f'Not enough data...\nData for Upper = {check1}\nData for Lower = {check2}')
#      84
# ---> 85     return newDF_train, newDF_test
#      86
#      87 def SaveData (trainDirectory, testDirectory, trainDF, testDF):
#
# UnboundLocalError: local variable 'newDF_train' referenced before assignment

# %%
files = ['reviews_Video_Games.json.gz', 
         'reviews_Toys_and_Games.json.gz', 
         'reviews_Sports_and_Outdoors.json.gz', 
         'reviews_Movies_and_TV.json.gz',
         'reviews_Kindle_Store.json.gz', 
         'reviews_Home_and_Kitchen.json.gz',
         'reviews_Health_and_Personal_Care.json.gz', 
         'reviews_Electronics.json.gz',
         'reviews_Clothing_Shoes_and_Jewelry.json.gz',
         'reviews_Cell_Phones_and_Accessories.json.gz', 
         'reviews_CDs_and_Vinyl.json.gz',
         'reviews_Books.json.gz']
filesNames = ['reviews_Video_Games', 
              'reviews_Toys_and_Games',
              'reviews_Sports_and_Outdoors', 
              'reviews_Movies_and_TV',
              'reviews_Kindle_Store', 
              'reviews_Home_and_Kitchen',
              'reviews_Health_and_Personal_Care', 
              'reviews_Electronics',
              'reviews_Clothing_Shoes_and_Jewelry',
              'reviews_Cell_Phones_and_Accessories', 
              'reviews_CDs_and_Vinyl',
              'reviews_Books']

def dataFullSets(original, concatData, name):
    currentData = original
    appendData = pd.read_csv('../CleanedData/%s'%(concatData))
    appendData['Product'] = name
    newDF = pd.concat([currentData,appendData])
    return(newDF)

train_data = pd.read_csv('../CleanedData/%s_train.csv'%(filesNames[0]))
train_data['Product'] = filesNames[0]
test_data = pd.read_csv('../CleanedData/%s_test.csv'%(filesNames[0]))
test_data['Product'] = filesNames[0]
                        
for fileName in filesNames[1:]:
    concatName_train = str(fileName+'_train.csv')
    print(concatName_train)
    concatName_test = fileName+'_test.csv'
                        
    train_data = dataFullSets(train_data, concatName_train, fileName)
    test_data = dataFullSets(test_data, concatName_test, fileName)
    
SaveData(r'../CleanedData/train_data.csv', 
         r'../CleanedData/test_data.csv', 
         train_data, test_data)
# Out:
# reviews_Toys_and_Games_train.csv
# reviews_Sports_and_Outdoors_train.csv
# reviews_Movies_and_TV_train.csv
# reviews_Kindle_Store_train.csv
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# reviews_Home_and_Kitchen_train.csv
# reviews_Health_and_Personal_Care_train.csv
# reviews_Electronics_train.csv
# reviews_Clothing_Shoes_and_Jewelry_train.csv
# reviews_Cell_Phones_and_Accessories_train.csv
# reviews_CDs_and_Vinyl_train.csv
# reviews_Books_train.csv

# %%
train_data
# Out:
#                    Product        asin     helpful  overall  \
# 0      reviews_Video_Games  B0054JGGGY      [0, 0]      5.0
# 1      reviews_Video_Games  B00008XL0A      [0, 0]      1.0
# 2      reviews_Video_Games  B007ZRZF8I      [4, 5]      1.0
# 3      reviews_Video_Games  B00009IM29      [0, 0]      5.0
# 4      reviews_Video_Games  B0009VXAM0   [14, 104]      5.0
# 5      reviews_Video_Games  B00CX9L30W     [1, 12]      1.0
# 6      reviews_Video_Games  B000B43OY4     [6, 11]      1.0
# 7      reviews_Video_Games  B004FYEZMQ     [8, 28]      5.0
# 8      reviews_Video_Games  B007FTE2VW      [2, 2]      1.0
# 9      reviews_Video_Games  B003ZHQH02    [16, 18]      5.0
# 10     reviews_Video_Games  B007FTE2VW      [4, 4]      1.0
# 11     reviews_Video_Games  B00DJFIMW6      [0, 0]      5.0
# 12     reviews_Video_Games  B007FMSDU0      [5, 7]      5.0
# 13     reviews_Video_Games  B001Q96ZNU    [11, 17]      1.0
# 14     reviews_Video_Games  B00CMQTVK0      [3, 4]      5.0
# 15     reviews_Video_Games  B0041TD3O6    [16, 22]      1.0
# 16     reviews_Video_Games  B00166N6SA      [0, 1]      1.0
# 17     reviews_Video_Games  B002J44BXW      [0, 1]      5.0
# 18     reviews_Video_Games  B004Z4ZK7K    [13, 19]      1.0
# 19     reviews_Video_Games  B003S2MXRA      [0, 0]      5.0
# 20     reviews_Video_Games  B000FKBCX4      [1, 1]      1.0
# 21     reviews_Video_Games  B00CBQO930      [0, 0]      5.0
# 22     reviews_Video_Games  B000F1WDHW      [4, 4]      5.0
# 23     reviews_Video_Games  B00ANHBJBY      [0, 2]      1.0
# 24     reviews_Video_Games  B001YHX4B0      [0, 0]      5.0
# 25     reviews_Video_Games  B00004WMA3      [2, 3]      5.0
# 26     reviews_Video_Games  B000F5IH2I      [1, 1]      5.0
# 27     reviews_Video_Games  B002PF29BG      [0, 2]      1.0
# 28     reviews_Video_Games  B0047O2Q0M      [2, 2]      5.0
# 29     reviews_Video_Games  B000H956SU      [1, 1]      1.0
# ...                    ...         ...         ...      ...
# 99970        reviews_Books  0446581682    [14, 17]      1.0
# 99971        reviews_Books  B0096PK31G      [0, 0]      5.0
# 99972        reviews_Books  0140183884      [0, 5]      1.0
# 99973        reviews_Books  1892112604      [2, 9]      5.0
# 99974        reviews_Books  0446572985      [0, 0]      5.0
# 99975        reviews_Books  0884197379    [18, 20]      5.0
# 99976        reviews_Books  0307730409      [0, 0]      5.0
# 99977        reviews_Books  061596916X      [0, 0]      5.0
# 99978        reviews_Books  B00CL8F7EI      [0, 0]      5.0
# 99979        reviews_Books  1937475670      [0, 1]      5.0
# 99980        reviews_Books  0810935570      [0, 0]      1.0
# 99981        reviews_Books  B004EEOIX8      [0, 1]      1.0
# 99982        reviews_Books  0345368509      [0, 0]      5.0
# 99983        reviews_Books  0976078090      [2, 9]      1.0
# 99984        reviews_Books  B00CIB2ICM      [0, 0]      1.0
# 99985        reviews_Books  0439136350     [1, 27]      1.0
# 99986        reviews_Books  0987861840      [1, 3]      5.0
# 99987        reviews_Books  0156278111      [0, 0]      5.0
# 99988        reviews_Books  0072133716      [0, 1]      5.0
# 99989        reviews_Books  143917282X  [122, 154]      1.0
# 99990        reviews_Books  0066620147    [13, 17]      1.0
# 99991        reviews_Books  0375804765      [0, 0]      5.0
# 99992        reviews_Books  1469237164      [1, 4]      1.0
# 99993        reviews_Books  1576753344      [0, 0]      5.0
# 99994        reviews_Books  0805098143      [0, 0]      5.0
# 99995        reviews_Books  B007C6VAK4   [65, 101]      1.0
# 99996        reviews_Books  031612351X      [0, 0]      5.0
# 99997        reviews_Books  0143058754      [0, 4]      1.0
# 99998        reviews_Books  044656740X      [7, 7]      1.0
# 99999        reviews_Books  B00GCY6BDS      [0, 0]      5.0
#
#                                               reviewText   reviewTime  \
# 0      it is working perfect Best mouse for hand perf...  02 23, 2014
# 1      If your going to buy a hits game save yourself...   01 3, 2014
# 2      Pay 2 play?  Please! Bad idea.Go look up OpenF...   06 7, 2012
# 3      I have been buying Madden for the past--oh a l...   11 7, 2003
# 4      This is the best system ever!!!  Buy it asap. ...  11 17, 2006
# 5      SE is doing really bad job at maintaining serv...   09 1, 2013
# 6      I bought the Xbox 360 premium system 3 weekend...  10 18, 2006
# 7      I understand there's a controversy on the endi...   06 6, 2012
# 8      So far, all that is able to be done with this ...   03 6, 2013
# 9      As soon as i saw this game i had to get it. Af...  11 20, 2010
# 10     If you could actually play the game, it would ...   03 7, 2013
# 11     I love this game. It is so addictive! It is a ...  03 28, 2014
# 12     Fortunately, I thought it was fantastic. Being...  10 30, 2012
# 13     I really want to play this game. It looks grea...  09 24, 2009
# 14     This console is Amazing...No Lie you will love...  11 28, 2013
# 15     This product was advertized as an nintendo wii...   06 2, 2011
# 16     It was not what I expected because the disc wa...   11 3, 2013
# 17     They work wonderfully, I thought I might have ...  01 28, 2013
# 18     I was hopeful FIFA 12 for the 3DS was going to...  09 29, 2011
# 19     I've played the demo 2 times after I bought th...   07 8, 2012
# 20     Both me and my son were looking forward to Spo...  09 14, 2008
# 21     This gaming mouse is excellent for anybody who...   12 3, 2013
# 22     I've been through hell and back trying to find...  10 31, 2011
# 23     This controller sucks. It did not sync at all ...   06 5, 2014
# 24     This is one of the hypest games I ever played,...  03 21, 2014
# 25     This game has to be one of the most funnest ga...  11 18, 2002
# 26     This is def. one of my favorite Final Fantasy ...  03 19, 2012
# 27     I purchased this game quite a while ago for my...  10 30, 2010
# 28     I'm not a racing fan, but this game is surpris...  03 26, 2012
# 29     I returned this guitar originally thinking may...  07 24, 2007
# ...                                                  ...          ...
# 99970  Call me a glutton for punishment.  I thought T...  06 24, 2008
# 99971  Find Your Soulmate-A Wiccan Guide is designed ...  10 28, 2012
# 99972  The author sends naive hero on a crazy journey...   02 4, 2014
# 99973  This is a must read for every woman who is a w...  11 14, 2010
# 99974  I couldn't put this down. It's a familiar form...  06 24, 2013
# 99975  I am so grateful for men of God like Lee Grady...   08 8, 2005
# 99976  Even though this is the second book in a serie...  03 19, 2013
# 99977  I would reccommend this book to everyone.  I h...  02 24, 2014
# 99978  This book is full of good information and reso...  10 16, 2013
# 99979  If you already know this book and the series f...   08 4, 2013
# 99980  Despite the attractive photographs, the book i...  02 10, 2005
# 99981  El libro tiene algunas secciones donde solo ap...   08 1, 2011
# 99982  I also was really shocked when I found book 6 ...   12 1, 1998
# 99983  This book was horribly written - it's really j...   07 5, 2006
# 99984  The points are missing from the anatomy diagra...   01 4, 2014
# 99985  I can't review this item because I never recei...  08 24, 2007
# 99986  This was a definite win for me to be able to g...  09 24, 2012
# 99987  This book is recommended to readers who have a...  08 31, 2009
# 99988  I have been coding php for about 4 months, I h...  01 21, 2002
# 99989  I am a fan of J. W. Rawles and an avid reader ...  09 27, 2012
# 99990  Maybe it's just me, but I'd rather read a book...  01 25, 2000
# 99991  The best fingerplay book for children Ever!  O...  04 20, 2014
# 99992  Very slooooow moving and boring, half of the b...   02 9, 2014
# 99993  Good book just a little confusing at times. It...   12 6, 2012
# 99994  It's always been clear that Benjamin Black (ak...   04 7, 2014
# 99995  Despite posing the question "Am I black enough...   04 8, 2012
# 99996  This was a great follow up to Beautiful Darkne...  05 10, 2013
# 99997  The inability to enlarge or read the maps in t...  11 29, 2013
# 99998  if you've seen one of these &quot;get rich qui...   10 7, 2002
# 99999  It was a fast read but interesting premise. I ...  11 15, 2013
#
#                   reviewerID                reviewerName  sentiment  \
# 0              AAIYP75T4H0L5              Ahmet Yildirim          1
# 1             A2141HXMIBTPG4                Drew Danuser          0
# 2             A3B43K6X4NFXG0                  checkedout          0
# 3              AZQ2UJF0H3TWF                        Paul          1
# 4             A39XNRYKE61XZY                 Nate "Nate"          1
# 5             A3L1I85NHMBHH0                      JxK718          0
# 6             A1BCY2DJGNBUQM              Freakin Sledge          0
# 7             A39WJNB2K0L73B             Amazon Customer          1
# 8             A3GHELK2AA6CLE                         NaN          0
# 9             A2UT0AFICK4XIS              A. Bettencourt          1
# 10            A3OY5IWZT8OUXF                         NaN          0
# 11            A2TR1QQFX57CLR                Alison Smith          1
# 12             AYGZPH8RLIQYS                 Losermagnet          1
# 13            A11A9AVEM5EVU4       James Papas "Treecat"          0
# 14            A3AFSFKO95DXJK             Mike Bronokoski          1
# 15            A2OCSJ1U7LNUM9  James Ebeling "Movie Buff"          0
# 16             AXHNYR67KT5CT                     Gabriel          0
# 17            A1H5KTNXCQQPXS                       Robyn          1
# 18            A18D8C2DGQ2SS2           Christian Bullock          0
# 19            A2BKLVCY4OU7FR           Justin A. Stewart          1
# 20            A3Q2O00LIZ1ZUY           sleepy in Seattle          0
# 21            A1CJAB63G98IP6                       CariS          1
# 22            A26U091ZD3IPTU                   J. Thomas          1
# 23            A2II1T5YEWA474                   Mardonius          0
# 24            A3S00T2Y0VCHT2               Tariq Forrest          1
# 25            A2TXU2FMSXSBNC              "windrider619"          1
# 26             ASLSX3EUZAYWK                      amanda          1
# 27            A2VI24VXIU2NPY               E. Slockbower          0
# 28             A715UTKDU9CZL         motaku96 "motaku96"          1
# 29             A8TWPL3MU520P       Joseph Bednarz "JoeB"          0
# ...                      ...                         ...        ...
# 99970         A2SGA8NQP2D61Q                  Lela "TLC"          0
# 99971  A09818901XA8TI5VC6FZK                 Chip Wilson          1
# 99972         A21W18RO9JNAKC                Himeko Inaba          0
# 99973           AFR0S1VDCAX7                        anna          1
# 99974           AIEGWTHP0OCW                 Dianimal911          1
# 99975         A1ZRYNMSM1P1TA  Tony, a grateful Christian          1
# 99976         A34B3I1SSF1IPH                    Mara Kim          1
# 99977         A3LOPV28UO9X99           Michelle Spradlin          1
# 99978         A3R4E0ON1MD4CH        Kristopher W. Bailey          1
# 99979         A3EQ52L5W6Y4F2                Fred Beckman          1
# 99980         A2YGAMNYADZK9H                 Lutyens Fan          0
# 99981         A2ZA2R8HBYQ246                     Anthony          0
# 99982         A25D1YARMT68A7     Keith Kyzivat "keithel"          1
# 99983         A285B1AHE1METU             Connecticut Joe          0
# 99984         A2QLM8MYZLLG3I                     P. Wong          0
# 99985         A101J1P0VHPFM4                  C. Stewart          0
# 99986         A1H3S85JCPDZ32                   JacquieMT          1
# 99987         A12NUP9FGSAVCR               Tomm "Rookie"          1
# 99988         A2ZRB4AUKZMD4Y             Zachary Setliff          1
# 99989          A731D29S03A0F            Colorado Prepper          0
# 99990          A4ZVS4DPTV2IK                  Jimmy Dean          0
# 99991          APPSXFRLVD29E                     janie21          1
# 99992         A3BBCRTX1JUK56                    D. Bouse          0
# 99993          A9XOCXEQGY051                CJ "area526"          1
# 99994         A3FIBHKU3DWM13        Edmund A. Marcarelli          1
# 99995         A3UCT16AESLK0W                        KPOM          0
# 99996         A2YIICW5DQ4MLK                      Robert          1
# 99997          A26TFW414OP7E           Richard P Massony          0
# 99998         A2SGET0QQF23LT                         bob          0
# 99999         A2VZ7I2MPZ0E12                         Mjb          1
#
#                                                  summary  unixReviewTime
# 0                                                perfect      1393113600
# 1                                               Terrible      1388707200
# 2                         Never trust OpenFeint.  Ever !      1339027200
# 3                                           Nice Touches      1068163200
# 4                                            ROCKIN' FUN      1163721600
# 5        Might be great game but very bad at maintaining      1377993600
# 6                            Totally not what I expected      1161129600
# 7                                    Massively Effective      1338940800
# 8                             Do not purchase this game!      1362528000
# 9                       Mario Vs DK has still got class!      1290211200
# 10                                   Do NOT buy SimCity.      1362614400
# 11                                              SOOO FUN      1395964800
# 12     There's a game in this box, and it may be fant...      1351555200
# 13                   what a waste no sale secure rom drm      1253750400
# 14                                                review      1385596800
# 15                                     False advertising      1306972800
# 16                            Did not give enough detail      1383436800
# 17                                              Thrilled      1359331200
# 18                         Terribly disappointing effort      1317254400
# 19                                           Great game!      1341705600
# 20                I only buy games that I own afterwards      1221350400
# 21                                           Comfortable      1386028800
# 22     Stop wasting your money on the Microsoft Headset!      1320019200
# 23                                               Nyko...      1401926400
# 24             If you're thinking about it, just get it.      1395360000
# 25     Love it but if you sell it to me for lower i w...      1037577600
# 26                                      One of the best!      1332115200
# 27                                     Outdated Graphics      1288396800
# 28                                Excellent arcade racer      1332720000
# 29               don't use this guitar with GuitarHero 2      1185235200
# ...                                                  ...             ...
# 99970                                    SAVE YOUR MONEY      1214265600
# 99971                                     Wicca and Love      1351382400
# 99972                  HAY LOOK HE'S RIDING AN ELUHFANT!      1391472000
# 99973                        Created to be his help meet      1289692800
# 99974                      Fun read, great new character      1372032000
# 99975                   Thank you! Thank you! Thank you!      1123459200
# 99976                                      Story of Hope      1363651200
# 99977                                 very enjoable read      1393200000
# 99978                                  Wow! Great stuff!      1381881600
# 99979                             Stories with Character      1375574400
# 99980                               All sizzle--no steak      1107993600
# 99981                       LAS IMAGENES NO SON VISIBLES      1312156800
# 99982        Not as good as the first 5, but still great       912470400
# 99983                                        Absurdistan      1152057600
# 99984       Points not visible in Kindle edition on iPad      1388793600
# 99985                                not really a review      1187913600
# 99986                         Highly recommend this read      1348444800
# 99987                              i laughed very loudly      1251676800
# 99988                                          Very Nice      1011571200
# 99989                           Founders by James Rawles      1348704000
# 99990                  That's a heck of a caveat, Bobby.       948758400
# 99991                                               Best      1397952000
# 99992                                          wasted $$      1391904000
# 99993                                          Good book      1354752000
# 99994      Black Delivers a Chanler-Worthy Marlowe Story      1396828800
# 99995                                Shame on Australia.      1333843200
# 99996                                    Excellent Book!      1368144000
# 99997                                  Mayflower:A Story      1385683200
# 99998              keep the poor kids away from this one      1033948800
# 99999                                          Fast read      1384473600
#
# [1200000 rows x 11 columns]

# %%
test
# Out:
#              reviewerID        asin  \
# 2236870  A16O9V0N14TQXL  B00HR8JMZM
# 1192676  A38B2QF2M0BX8G  B003JSSAHU
# 2229673  A2P6ZQRMHTM5TR  B00GZ1GUSY
# 1039177  A2CIJ9CZ5YUB0Q  B002V1H0WW
# 2185422  A1113QZDZX7ADU  B00F3TKLRA
# 145153    ABJY7LAG572T8  B00007L12O
# 2228585   AB9KWWWADOKG1  B00GWTGFNO
# 2146802  A38CJRYE1A9WNR  B00DQ99NT6
# 484810   A34H8TMO9Z0DNL  B000JNE658
# 1838367  A3PDW0BHDVII1S  B008C2EY6O
# 1034626  A2B7GYO1V8ZRV1  B002U5ZXS2
# 315000   A1SDLZMUEA1JNS  B0009PU0UQ
# 224815   A3B8BIDNZF1IOT  B0002HZLU0
# 1130105   AOB2OFH2KFHZD  B0039X6XZG
# 350832   A1K9BQN9J8A6B3  B000BR0FXO
# 804025   A2B88WI9N14THL  B001F58LO6
# 753836   A2UHVZK2X66C4C  B00193P61A
# 767567   A2NTAGGAPLK63P  B001ASEU3Y
# 422618   A1F31US4R4DO7O  B000FWAFAS
# 1229661   A5BVT2XCVG3B3  B003U8XYZM
# 1767151  A2TCZC3RK48OHK  B007RTFZLQ
# 334016   A3RRK9PUUWFZH1  B000B6MKMO
# 1612458   APUI5TIIS30U3  B005VPRF98
# 1781818  A2T1FYOYW8237H  B007XGXI9O
# 1477748   A74QE0Q87EV4C  B004W49AK6
# 2067211  A2UQ3VS4H6DNQF  B00C81LYH2
# 1041415  A2Q2QCKJY67JUH  B002VD0DRO
# 428768    A9AW3UUZZVPTC  B000GECCHY
# 1998396  A275VR1WGNCZPO  B00B1BPR5A
# 859039    ALJV92MSX4D9W  B001PIJEFS
# ...                 ...         ...
# 1322679  A22FBXZLU3K0U9  B004ANTFZO
# 169716   A39L5TBL7L95P2  B00009QOQG
# 1776118   AYF1XG9OJJSZB  B007UPS8VQ
# 1517128  A17D5QGCZ9L6UQ  B00538F8YW
# 945650   A2XJPTLIPEA17C  B0029UFO9G
# 1589255  A1CIV3N9HVMQ89  B005OHLAG2
# 2228191   AMY7QUV1MGLPJ  B00GVHEQV0
# 511887   A2J536HVLU06N7  B000M6F1CO
# 1418852  A3VYNHI8S4MMVP  B004PRURRK
# 1417074   ACM5DCR1S594D  B004PBO9MA
# 880853   A29I9SK4KHLPCD  B001T1CBZQ
# 1355418  A3L63XRCNCISP4  B004H1V5RU
# 1500000  A2CQ99W0NFVGEE  B004ZKPYAW
# 807664   A1HNWQQ14474ZC  B001FVSZ8C
# 2058552  A3VY2AEXFCVZQ8  B00C5CH88I
# 2245381  A23NRSACQ30ME9  B00IOT368M
# 1422379   AFJXTK5A9EWTI  B004QEZLLO
# 516104    AR2XDGD6GRJFM  B000MOHAB6
# 385914    AYV21CGNNXRPL  B000ETQR36
# 594657    AX6H1BYCPS3U1  B000SAH5I2
# 1363346   AS89HFRVBJ4X8  B004IBXEDW
# 1345368  A3OZ53APPWVJKD  B004FEXUP4
# 232305   A2XIMIFJHULD14  B0002VNPL8
# 1120052   A7WXL4QTEREOW  B0038L1Y58
# 1390624  A2F94K0MBWHRPA  B004MYH0BC
# 2140675   AU2PZO6TXM717  B00DPGV320
# 1353157   AKQ4UQE9T3N3Z  B004GT9OW6
# 1024263   AOPJR1E2PK7X6  B002SBYGOK
# 1360978  A16JVCL1ELIP82  B004I07C9A
# 968145   A37UY0KN1SALNK  B002FEFVBC
#
#                                         reviewerName   helpful  \
# 2236870                                       Jasper    [0, 0]
# 1192676                                          sam    [0, 0]
# 2229673                                Aaron Edwards    [0, 0]
# 1039177                                     Kimberly    [2, 2]
# 2185422                                     Hanna Mh  [10, 11]
# 145153                                    A. Coleman   [7, 33]
# 2228585                                     Julio S.    [0, 0]
# 2146802                                 Blake Herman    [0, 2]
# 484810                          Victoria C. El-Zarif    [0, 1]
# 1838367                                     veronica    [0, 0]
# 1034626                              dmc333 "dmc333"    [1, 1]
# 315000                                        anasia    [4, 4]
# 224815                                        Autumn  [10, 12]
# 1130105                                         0000    [2, 4]
# 350832                                             N    [0, 0]
# 804025                  Erin K. Seitz "mom of three"    [1, 1]
# 753836                                     Mary Krug    [0, 0]
# 767567                                       Ms Bill    [0, 0]
# 422618                                 Richard Brady    [0, 0]
# 1229661                 Sherri L. Lind "busygrandma"    [0, 0]
# 1767151                                      btmommy    [0, 0]
# 334016                                   Jason Heiss    [1, 1]
# 1612458                                 patty norman    [0, 0]
# 1781818                                        Nancy    [0, 1]
# 1477748                                    redbee305    [0, 2]
# 2067211                                    Dubya2014    [0, 0]
# 1041415              Ms. Sandra D. Seals "Book Worm"    [2, 2]
# 428768                         John Patrick Fischner    [5, 5]
# 1998396                               Brenda Herndon    [0, 0]
# 859039                                         Laura    [0, 0]
# ...                                              ...       ...
# 1322679                                Sarah Gashkin    [3, 7]
# 169716   Miriam Van Scott "Candy Canes in Bethlehem"  [51, 53]
# 1776118                                            L    [0, 0]
# 1517128                                   Mom3wifeme    [0, 0]
# 945650                              Mary Ellen Flynn  [13, 19]
# 1589255                                         doug    [0, 0]
# 2228191                                         Jodi   [4, 13]
# 511887                        Online buyer "Fortune"    [1, 7]
# 1418852                           Lita M. Hildebrand    [2, 4]
# 1417074                                    Diet Girl    [0, 0]
# 880853                Rebecca P. Wilkinson "Rebecca"    [0, 0]
# 1355418                                Amy C. Spidle    [0, 0]
# 1500000                                          Tab    [0, 0]
# 807664                            Mary Jane Langston    [5, 6]
# 2058552                               Pamela K. Barr    [0, 0]
# 2245381                                        Clavk    [0, 3]
# 1422379                               Muhtarom Davis    [0, 2]
# 516104                                   Traci Askew    [0, 0]
# 385914                     H. Morgan "bruinschick13"    [0, 0]
# 594657                                    shoe lover    [2, 7]
# 1363346                                     M. Moore    [0, 0]
# 1345368                                    alissab31    [0, 0]
# 232305                                           LMM    [1, 1]
# 1120052                                   susan byrd    [0, 0]
# 1390624                                     gioabram   [0, 10]
# 2140675                                      AmyGenn    [1, 2]
# 1353157                                        NanaJ    [1, 1]
# 1024263                                      Donovan    [0, 0]
# 1360978                                  Jimmy N Va.    [0, 0]
# 968145                                          Josh    [0, 1]
#
#                                                 reviewText  overall  \
# 2236870                                   My son loved it!      5.0
# 1192676  These birds were very pretty, but it was hard ...      1.0
# 2229673  I owned the PS3 version for a little while, tr...      5.0
# 1039177  This float is durable and very roomy for two p...      5.0
# 2185422  I just received these bands and they smell hor...      1.0
# 145153   I ordered this tool set for my grandson, age 2...      1.0
# 2228585  @Broadway Lumber Supplies we value every singl...      5.0
# 2146802  Ours lasted about 10 minutes and then died.  W...      1.0
# 484810   The purchase was smooth and the item posted pr...      5.0
# 1838367  I got this to use as a little cake topper for ...      1.0
# 1034626  The reviewer who gave this figure one star is ...      5.0
# 315000   Started to fill with water, had to patch 4 hol...      1.0
# 224815   These had a horrible toxic smell to them when ...      1.0
# 1130105  i got it at a store the light saber was 9 inch...      1.0
# 350832   The lights and sounds didn't even work when it...      1.0
# 804025   My daughter has two of these.  They are very c...      1.0
# 753836   Good gag gift gave them to our grandsons and t...      5.0
# 767567   Save your hard-earned dollar, Folks.  The pric...      1.0
# 422618   I needed these exact screws for a computer app...      5.0
# 1229661  Excellent, well-made toy in the Fisher-Price t...      5.0
# 1767151  Perfect gift for a 5-6 year old!  My son LOVES...      5.0
# 334016   We got this so our two year old would have a s...      5.0
# 1612458  it is a very very good item,i am very much loo...      5.0
# 1781818  DONT BUY!! CAN NOT BE USED DUE TO DAMAGING REE...      1.0
# 1477748  We purchased this car for our grandson.  From ...      1.0
# 2067211  Ive been getting these for 20 years for my nie...      5.0
# 1041415  I am in a Medical Assistant Class and use this...      5.0
# 428768   Look hard at that 5 inch hight measurement. It...      1.0
# 1998396  I love my Michonne doll, the quality is good a...      5.0
# 859039   I bought this for a diorama I'm making to depi...      5.0
# ...                                                    ...      ...
# 1322679  I took my kids toys to the labratory and they ...      1.0
# 169716   This toy looks great, but the Amazon spec desc...      1.0
# 1776118  Even for the cheap price it wasn't worth the p...      1.0
# 1517128  I got these as part of party favors and the ki...      5.0
# 945650   I cannot believe some the positive reviews on ...      1.0
# 1589255                                       good product      5.0
# 2228191  Left in mailbox in winter in Montana. Came hom...      1.0
# 511887   The item I received came promptly and in good ...      5.0
# 1418852  This was broken when I received it, and my com...      1.0
# 1417074  I bought it for a new mommy-to-be decorating h...      5.0
# 880853   Very sturdy- my grandson loves it and I love t...      5.0
# 1355418  My son LOVES it!  He has the other Perplexus b...      5.0
# 1500000  Have looked for this product at local fabric s...      5.0
# 807664   Hard and time consuming to assemble.  the boys...      1.0
# 2058552  I thought my 5 year old granddaughter would lo...      1.0
# 2245381  Be careful ordering these. I bought them for m...      1.0
# 1422379  Wow... As soon as I received my Central Statio...      5.0
# 516104   This was one of my daughter's first schleich a...      5.0
# 385914   my son (8 yrs) got this for christmas and he p...      5.0
# 594657   This looks like an awsome product and some of ...      1.0
# 1363346  Bought this for a friend's baby, very pleased ...      5.0
# 1345368  Didn't ever work. Left in sun too.  Super tiny...      1.0
# 232305   My daughter loved playing with this. Then afte...      1.0
# 1120052  Completely overpriced.  I did not read the des...      1.0
# 1390624  It is just a case! without a cars! The Photo i...      1.0
# 2140675  Potentially dangerous in the wrong hands.  I b...      1.0
# 1353157  Tried two (of a 12 pack) of these balloon heli...      1.0
# 1024263  The mouth pieces I was sent are a different br...      1.0
# 1360978  I really love this toy , it says everything I ...      1.0
# 968145   Well it sucks. i got it charged the battery fo...      1.0
#
#                                                    summary  unixReviewTime  \
# 2236870                                         Five Stars      1405123200
# 1192676                      little warble in pretty birds      1310860800
# 2229673                                         Great Game      1395705600
# 1039177                                  Durable and roomy      1305504000
# 2185422                         Horrible Discusting Smell!      1391385600
# 145153                                Kids Garden Tool Set      1210723200
# 2228585              Beautiful material worth every penney      1396569600
# 2146802                          Works great when it works      1388188800
# 484810                                               Fun!!      1309478400
# 1838367                             Don t waste your money      1404086400
# 1034626                            This figure is amazing!      1390953600
# 315000                                              Leaker      1377734400
# 224815                                      Toxic Smelling      1324598400
# 1130105                                               lame      1328745600
# 350832                          Was broken when it arrived      1376352000
# 804025                                            not safe      1236556800
# 753836                                             So cute      1375056000
# 767567                          Crummy deal on crappy dice      1387843200
# 422618                                    They are perfect      1375574400
# 1229661                                      Well-made toy      1331769600
# 1767151                                       Fantastic!!!      1357084800
# 334016                                          Race Cars!      1242691200
# 1612458                                             great.      1387584000
# 1781818  DONT BUY!!! CAN NOT BE USE OVERSEA/DAMAGING REEFS      1400889600
# 1477748                                         Bad choice      1324944000
# 2067211                                      ''Barbie Doll      1388620800
# 1041415                                              Great      1390089600
# 428768                     Great Photo!  Beware!!!!!!!!!!!      1285718400
# 1998396         Michonne is fearsome and I love this doll.      1379030400
# 859039                                              Sturdy      1391904000
# ...                                                    ...             ...
# 1322679                    Found %14 mercury on it's paint      1324857600
# 169716                             Batteries NOT included!      1090627200
# 1776118                                   Cute but a waste      1351209600
# 1517128                                  Great party favor      1380758400
# 945650                                    AWFUL PUZZLE!!!!      1280102400
# 1589255                                         Five Stars      1404086400
# 2228191                                        Frozen ants      1388448000
# 511887   collectable item for myself - very cool design...      1206662400
# 1418852                                     Piece of Junk.      1352505600
# 1417074                                     Adorable lion!      1387670400
# 880853                                     Teriffic Tunnel      1366675200
# 1355418                                           Awesome!      1324252800
# 1500000                                 Large Flower Maker      1327449600
# 807664                Star Wars theme is only saving grace      1239840000
# 2058552                               cheap, not well made      1388016000
# 2245381                                     Already opened      1403740800
# 1422379                                           Magician      1359072000
# 516104                                           Great toy      1385596800
# 385914                                          wonderful!      1168300800
# 594657                                            WARNING!      1233878400
# 1363346                                      excellent toy      1377820800
# 1345368                                   cute but a waste      1393113600
# 232305           I loved it -- then it broke after a month      1364947200
# 1120052                                      Action figure      1360886400
# 1390624                                  waisting of money      1324252800
# 2140675                                   Not a great toy.      1388880000
# 1353157                    Don't waste your time or money!      1396742400
# 1024263                           I do NOT reccomend these      1373673600
# 1360978                  hope yours works better than mine      1350432000
# 968145                                              Stupid      1374796800
#
#           reviewTime  sentiment
# 2236870  07 12, 2014          1
# 1192676  07 17, 2011          0
# 2229673  03 25, 2014          1
# 1039177  05 16, 2011          1
# 2185422   02 3, 2014          0
# 145153   05 14, 2008          0
# 2228585   04 4, 2014          1
# 2146802  12 28, 2013          0
# 484810    07 1, 2011          1
# 1838367  06 30, 2014          0
# 1034626  01 29, 2014          1
# 315000   08 29, 2013          0
# 224815   12 23, 2011          0
# 1130105   02 9, 2012          0
# 350832   08 13, 2013          0
# 804025    03 9, 2009          0
# 753836   07 29, 2013          1
# 767567   12 24, 2013          0
# 422618    08 4, 2013          1
# 1229661  03 15, 2012          1
# 1767151   01 2, 2013          1
# 334016   05 19, 2009          1
# 1612458  12 21, 2013          1
# 1781818  05 24, 2014          0
# 1477748  12 27, 2011          0
# 2067211   01 2, 2014          1
# 1041415  01 19, 2014          1
# 428768   09 29, 2010          0
# 1998396  09 13, 2013          1
# 859039    02 9, 2014          1
# ...              ...        ...
# 1322679  12 26, 2011          0
# 169716   07 24, 2004          0
# 1776118  10 26, 2012          0
# 1517128   10 3, 2013          1
# 945650   07 26, 2010          0
# 1589255  06 30, 2014          1
# 2228191  12 31, 2013          0
# 511887   03 28, 2008          1
# 1418852  11 10, 2012          0
# 1417074  12 22, 2013          1
# 880853   04 23, 2013          1
# 1355418  12 19, 2011          1
# 1500000  01 25, 2012          1
# 807664   04 16, 2009          0
# 2058552  12 26, 2013          0
# 2245381  06 26, 2014          0
# 1422379  01 25, 2013          1
# 516104   11 28, 2013          1
# 385914    01 9, 2007          1
# 594657    02 6, 2009          0
# 1363346  08 30, 2013          1
# 1345368  02 23, 2014          0
# 232305    04 3, 2013          0
# 1120052  02 15, 2013          0
# 1390624  12 19, 2011          0
# 2140675   01 5, 2014          0
# 1353157   04 6, 2014          0
# 1024263  07 13, 2013          0
# 1360978  10 17, 2012          0
# 968145   07 26, 2013          0
#
# [20000 rows x 10 columns]

# %% [markdown]
# ## Loading Zhang et al. Yelp Polarity Data

# %%
yelp_train = pd.read_csv('../../Yelp-Zhang-train.csv', header = None)
yelp_train.columns = ['sentiment','reviewText']
yelp_train['sentiment'] = np.where(yelp_train['sentiment']==2,1,0)



yelp_test = pd.read_csv('../../Yelp-Zhang-test.csv', header = None)
yelp_test.columns = ['sentiment','reviewText']
yelp_test['sentiment'] = np.where(yelp_test['sentiment']==2,1,0)

# %%
yelp_train.head(3)
# Out:
#    sentiment                                         reviewText
# 0          0  Unfortunately, the frustration of being Dr. Go...
# 1          1  Been going to Dr. Goldberg for over 10 years. ...
# 2          0  I don't know what Dr. Goldberg was like before...

# %%
yelp_test.head(3)
# Out:
#    sentiment                                         reviewText
# 0          1  Contrary to other reviews, I have zero complai...
# 1          0  Last summer I had an appointment to get new ti...
# 2          1  Friendly staff, same starbucks fair you get an...

# %%
SaveData(r'../../yelp_zhang_pol_train.csv', 
         r'../../yelp_zhang_pol_test.csv', 
         yelp_train, yelp_test)

# %%
Amazon_Zhang_Polarity_test = pd.read_csv('../../Amazon-Zhang-Polarity-test.csv', header = None)

# %%
Amazon_Zhang_Polarity_test.head()
# Out:
#    0                                                  1  \
# 0  2                                           Great CD
# 1  2  One of the best game music soundtracks - for a...
# 2  1                   Batteries died within a year ...
# 3  2              works fine, but Maha Energy is better
# 4  2                       Great for the non-audiophile
#
#                                                    2
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
# 2  I bought this charger in Jul 2003 and it worke...
# 3  Check out Maha Energy's website. Their Powerex...
# 4  Reviewed quite a bit of the combo players and ...

# %%
Amazon_Zhang_Polarity_test.columns = ['sentiment','reviewTitle','reviewText']
Amazon_Zhang_Polarity_test['sentiment'] = np.where(Amazon_Zhang_Polarity_test['sentiment']==2,1,0)

# %%
Amazon_Zhang_Polarity_test.to_csv(r'../../Amazon_Zhang_Polarity_test.csv', index = None, header=True)

# %%
max_length = 200

def loadData(loadDat = True, #test_data = test_data, train_data = train_data, 
             #yelp_zhang_train = yelp_zhang_train, yelp_zhang_test = yelp_zhang_test, 
             amazon_zhang_test = Amazon_Zhang_Polarity_test):
    
    if loadDat == True:
#         train_data_name = '../../train_data_cleaned.pkl'
#         train_data = pd.read_pickle(train_data_name)
        
#         test_data_name = '../../train_data_cleaned.pkl'
#         test_data = pd.read_pickle(test_data_name)
        
#         play_data_name = '../../play_data_cleaned.pkl'
#         play_data = pd.read_pickle(play_data_name)
        
#         twitter_reviews_name = '../../twitter_reviews_cleaned.pkl'
#         twitter_reviews = pd.read_pickle(twitter_reviews_name)
        
#         imdb_test_name = '../../imdb_test_cleaned.pkl'
#         imdb_test = pd.read_pickle(imdb_test_name)
#         imdb_train_name = '../../imdb_train_cleaned.pkl'
#         imdb_train = pd.read_pickle(imdb_train_name)
        
#         yelp_reviews_name = '../../yelp_reviews_cleaned.pkl'
#         yelp_reviews = pd.read_pickle(yelp_reviews_name)
        
#         yelp_zhang_train_name = '../../yelp_zhang_pol_train_cleaned.pkl'
#         yelp_zhang_train = pd.read_pickle(yelp_zhang_train_name)
#         yelp_zhang_test_name = '../../yelp_zhang_pol_test_cleaned.pkl'
#         yelp_zhang_test = pd.read_pickle(yelp_zhang_test_name)
        
#         sst_test_name = '../../sst_test.pkl'
#         sst_test = pd.read_pickle(sst_test_name)
        
        amazon_zhang_test_name = '../../amazon_zhang_pol_test_cleaned.pkl'
        amazon_zhang_test = pd.read_pickle(amazon_zhang_test_name)
        
#         print('Successfully opened pickled data')
        
#         return train_data, test_data, play_data, twitter_reviews, imdb_test, imdb_train, yelp_reviews, yelp_zhang_train, yelp_zhang_test, sst_test, amazon_zhang_test
        return amazon_zhang_test
    else:

        #play_data = test_data[:10]

        def decontracted(phrase):
            phrase = re.sub(r"won\'t", "will not", phrase)
            phrase = re.sub(r"can\'t", "can not", phrase)
            phrase = re.sub(r"n\'t", " not", phrase)
            phrase = re.sub(r"\'re", " are", phrase)
            phrase = re.sub(r"\'s", " is", phrase)
            phrase = re.sub(r"\'d", " would", phrase)
            phrase = re.sub(r"\'ll", " will", phrase)
            phrase = re.sub(r"\'t", " not", phrase)
            phrase = re.sub(r"\'ve", " have", phrase)
            phrase = re.sub(r"\'m", " am", phrase)
            return phrase

        def prepReview(data):
            data_prep = str(data['reviewText'])
            data_prep = re.sub("[!?]", ".", data_prep)
            data_prep = re.sub("[^a-zA-Z']", " ", data_prep).lower()
            data_prep = re.sub("[\\s]+", " ", data_prep)
            data_prep = decontracted(data_prep)
            return data_prep

        #function to process review text and split into words
        def splitWords(data):
            return prepReview(data).split()[:max_length]

        #function to process review text and split into sentences
        def splitSentences(data):
            interim = prepReview(data).split()
            reviewTrunc = interim[:max_length]
            return ' '.join(reviewTrunc)


        #list of words from review into column
#         sentences = play_data.apply(splitWords, axis=1)
#         play_data.insert(loc = 11, column = 'sentenceWords', value = sentences)

#         sentences = train_data.apply(splitWords, axis=1)
#         train_data.insert(loc = 11,column = 'sentenceWords', value = sentences)

#         sentences = test_data.apply(splitWords, axis=1)
#         test_data.insert(loc = 11,column = 'sentenceWords', value = sentences)

#         #IMDB additions
#         sentences = imdb_test.apply(splitWords, axis=1)
#         imdb_test.insert(loc = 6,column = 'sentenceWords', value = sentences)
        
#         sentences = imdb_train.apply(splitWords, axis=1)
#         imdb_train.insert(loc = 6,column = 'sentenceWords', value = sentences)
        
#         sentences = twitter_reviews.apply(splitWords, axis=1)
#         twitter_reviews.insert(loc = 2,column = 'sentenceWords', value = sentences)
        
#         sentences = yelp_reviews.apply(splitWords, axis=1)
#         yelp_reviews.insert(loc = 2,column = 'sentenceWords', value = sentences)
        
#         sentences = yelp_zhang_train.apply(splitWords, axis=1)
#         yelp_zhang_train.insert(loc = 2,column = 'sentenceWords', value = sentences)
        
#         sentences = yelp_zhang_test.apply(splitWords, axis=1)
#         yelp_zhang_test.insert(loc = 2,column = 'sentenceWords', value = sentences)
        
#         sentences = sst_test.apply(splitWords, axis=1)
#         sst_test.insert(loc = 2,column = 'sentenceWords', value = sentences)
        
        sentences = amazon_zhang_test.apply(splitWords, axis=1)
        amazon_zhang_test.insert(loc = 2,column = 'sentenceWords', value = sentences)
        
        print('Finished working through the words for each sentences\nOn to the sentences..')

        #list of sentences from review into column
#         sentences_split = play_data.apply(splitSentences, axis=1)
#         play_data.insert(loc = 12, column = 'sentences', value = sentences_split)

#         sentences_split = train_data.apply(splitSentences, axis=1)
#         train_data.insert(loc = 12,column = 'sentences', value = sentences_split)

#         sentences_split = test_data.apply(splitSentences, axis=1)
#         test_data.insert(loc = 12,column = 'sentences', value = sentences_split)
        
#         #IMDB additions
#         sentences_split = imdb_test.apply(splitSentences, axis=1)
#         imdb_test.insert(loc = 7,column = 'sentences', value = sentences_split)

#         sentences_split = imdb_train.apply(splitSentences, axis=1)
#         imdb_train.insert(loc = 7,column = 'sentences', value = sentences_split)
        
#         sentences_split = twitter_reviews.apply(splitSentences, axis=1)
#         twitter_reviews.insert(loc = 3,column = 'sentences', value = sentences_split)
        
#         sentences_split = yelp_reviews.apply(splitSentences, axis=1)
#         yelp_reviews.insert(loc = 3,column = 'sentences', value = sentences_split)
        
#         sentences_split = yelp_zhang_train.apply(splitSentences, axis=1)
#         yelp_zhang_train.insert(loc = 2,column = 'sentences', value = sentences_split)
        
#         sentences_split = yelp_zhang_test.apply(splitSentences, axis=1)
#         yelp_zhang_test.insert(loc = 2,column = 'sentences', value = sentences_split)
        
#         sentences_split = sst_test.apply(splitSentences, axis=1)
#         sst_test.insert(loc = 3,column = 'sentences', value = sentences_split)
        
        sentences_split = amazon_zhang_test.apply(splitSentences, axis=1)
        amazon_zhang_test.insert(loc = 2,column = 'sentences', value = sentences_split)
        
        print('Finished sentences...\nNow moving on to pickling the data')

#         train_data_name = '../../train_data_cleaned.pkl'
#         train_data.to_pickle(train_data_name)
        
#         test_data_name = '../../test_data_cleaned.pkl'
#         test_data.to_pickle(test_data_name)
        
#         play_data_name = '../../play_data_cleaned.pkl'
#         play_data.to_pickle(play_data_name)
        
#         twitter_reviews_name = '../../twitter_reviews_cleaned.pkl'
#         twitter_reviews.to_pickle(twitter_reviews_name)
        
#         imdb_test_name = '../../imdb_test_cleaned.pkl'
#         imdb_test.to_pickle(imdb_test_name)
#         imdb_train_name = '../../imdb_train_cleaned.pkl'
#         imdb_train.to_pickle(imdb_train_name)
        
#         yelp_reviews_name = '../../yelp_reviews_cleaned.pkl'
#         yelp_reviews.to_pickle(yelp_reviews_name)

#         yelp_zhang_train_name = '../../yelp_zhang_pol_train_cleaned.pkl'
#         yelp_zhang_train.to_pickle(yelp_zhang_train_name)
#         yelp_zhang_test_name = '../../yelp_zhang_pol_test_cleaned.pkl'
#         yelp_zhang_test.to_pickle(yelp_zhang_test_name)
        
#         sst_test_name = '../../sst_test.pkl'
#         sst_test.to_pickle(sst_test_name)
        
        amazon_zhang_test_name = '../../amazon_zhang_pol_test_cleaned.pkl'
        amazon_zhang_test.to_pickle(amazon_zhang_test_name)
        
        print('Finished pickling for future use.')
        
        return amazon_zhang_test
        
amazon_zhang_test = loadData(loadDat = True)
        
#         return train_data, test_data, play_data, twitter_reviews, imdb_test, imdb_train, yelp_reviews, yelp_zhang_train, yelp_zhang_test, sst_test
        
# train_data, test_data, play_data, twitter_reviews, imdb_test, imdb_train, yelp_reviews, yelp_zhang_train, yelp_zhang_test, sst_test = loadData(loadDat = True)

# %%
amazon_zhang_test
# Out:
#         sentiment                                        reviewTitle  \
# 0               1                                           Great CD
# 1               1  One of the best game music soundtracks - for a...
# 2               0                   Batteries died within a year ...
# 3               1              works fine, but Maha Energy is better
# 4               1                       Great for the non-audiophile
# 5               0              DVD Player crapped out after one year
# 6               0                                     Incorrect Disc
# 7               0                           DVD menu select problems
# 8               1            Unique Weird Orientalia from the 1930's
# 9               0                            Not an "ultimate guide"
# 10              1                   Great book for travelling Europe
# 11              0                                               Not!
# 12              0                                    A complete Bust
# 13              1                           TRULY MADE A DIFFERENCE!
# 14              0                    didn't run off of USB bus power
# 15              0                                         Don't buy!
# 16              1             Simple, Durable, Fun game for all ages
# 17              1                  Review of Kelly Club for Toddlers
# 18              1                          SOY UN APASIONADO DEL BOX
# 19              1  Some of the best fiddle playing I have heard i...
# 20              0                                    Long and boring
# 21              0                                       Dont like it
# 22              1         one of the last in the series to collect !
# 23              1                    Sony Hi8 Camcorder with 2.5 LCD
# 24              0   Don't Take the Chance - Get the SE Branded Cable
# 25              0                                    Waste of money!
# 26              1                                        works great
# 27              0                                       Has No Range
# 28              1                     wish i had gotten this sooner!
# 29              0                     Three Days of Use and It Broke
# ...           ...                                                ...
# 399970          1                     This is my first PDA/Organizer
# 399971          0                                      Piece of Crap
# 399972          0          Okay at first, but died pretty quickly...
# 399973          1                    Great Little Speakers for Music
# 399974          1                                   Great Bench Kit!
# 399975          0                         Neil Armstrong, A Good Man
# 399976          1                                      Works great!!
# 399977          0          Huh? The CD's over? Best nap I ever took.
# 399978          1  The Celtic Knotwork Handbook, a perfect book f...
# 399979          1                      We love Mr. Putter and Tabby!
# 399980          0                  Not unless you're a time traveler
# 399981          0                                 not useful anymore
# 399982          0              MAC OS X SERVER Administrator's Guide
# 399983          0         Bulb: 10,000 hours; transformer: 250 hours
# 399984          0                                      Don't Buy Ott
# 399985          1                                             Super.
# 399986          1                 Extremely Useful for Me and Others
# 399987          1                        I like this keyboard a lot!
# 399988          0                                 Not for beginners!
# 399989          0  Cheap plasticy looking and can't see the light...
# 399990          1     I really love Puff Daddy and R. Kelly's songs.
# 399991          0                                  Very Disappointed
# 399992          0                            Strange but, listenable
# 399993          0                                               CRAP
# 399994          1                                   Obey the warning
# 399995          0                         Unbelievable- In a Bad Way
# 399996          0                    Almost Great, Until it Broke...
# 399997          0                                   Disappointed !!!
# 399998          1                            Classic Jessica Mitford
# 399999          0                        Comedy Scene, and Not Heard
#
#                                                 sentences  \
# 0       my lovely pat has one of the great voices of h...
# 1       despite the fact that i have only played a sma...
# 2       i bought this charger in jul and it worked ok ...
# 3       check out maha energy is website their powerex...
# 4       reviewed quite a bit of the combo players and ...
# 5       i also began having the incorrect disc problem...
# 6       i love the style of this but after a couple ye...
# 7       i cannot scroll through a dvd menu that is set...
# 8       exotic tales of the orient from the is dr shen...
# 9       firstly i enjoyed the format and tone of the b...
# 10      i currently live in europe and this is the boo...
# 11      if you want to listen to el duke then it is be...
# 12      this game requires quicktime to work if you ha...
# 13      i have been using this product for a couple ye...
# 14      was hoping that this drive would run off of bu...
# 15      first of all the company took my money and sen...
# 16      this is an awesome game almost everyone know t...
# 17      for the price of this pc game is well worth it...
# 18      y este libro est espl ndido lo disfrutas lo pu...
# 19      this is an excellent album with some great fid...
# 20      i have read this book with much expectation it...
# 21      this product smells when you open the package ...
# 22      the magazine was in very good condition and ha...
# 23      i believe i will be very happy with the camcor...
# 24      if you purchase this data cable you need to kn...
# 25      like many of the barbie cd roms the playtime i...
# 26      i bought this item to connect to a strobe ligh...
# 27      i suppose if you were going to sit in the same...
# 28      ive got a lamp in the corner of my room behind...
# 29      very disappointed in this product it worked pe...
# ...                                                   ...
# 399970  i purchased this about months ago and it reall...
# 399971  i have ordered thousands of items in my lifeti...
# 399972  my parents ordered me these new speakers when ...
# 399973  i like to listen to internet radio and cds whi...
# 399974  i made a small long warming bench for sitting ...
# 399975  neil a good man too bad he did not land or wal...
# 399976  i purchased the item hoping that it would fit ...
# 399977  ferry ferry ferry what are you doing i can not...
# 399978  if you are just getting started or have been i...
# 399979  my children ages three and five adore mr puute...
# 399980  this book is old and nigh unto useless unless ...
# 399981  while this book seemed very appealing for some...
# 399982  i was looking for a book that would be a guide...
# 399983  the bulb is rated for up to hours but the tran...
# 399984  buyers be warned i bought an ott lite a year a...
# 399985  this item is all i expected and more wooooow n...
# 399986  as a teacher and collegiate athletic coach i f...
# 399987  my keyboard at work is so easy to use that i h...
# 399988  there is way too much talking and detailed exp...
# 399989  buy this if u have money to spend on junk stuf...
# 399990  i am so happy they made this song together bec...
# 399991  i expected more about how to create luck maybe...
# 399992  this is not what i expected i thought this was...
# 399993  this is not music no matter what anyone says i...
# 399994  this is a fun toy and my and year olds love it...
# 399995  we bought this thomas for our son who is a hug...
# 399996  my son recieved this as a birthday gift months...
# 399997  i bought this toy for my son who loves the tho...
# 399998  this is a compilation of a wide range of mitfo...
# 399999  this dvd will be a disappointment if you get i...
#
#                                             sentenceWords  \
# 0       [my, lovely, pat, has, one, of, the, great, vo...
# 1       [despite, the, fact, that, i, have, only, play...
# 2       [i, bought, this, charger, in, jul, and, it, w...
# 3       [check, out, maha, energy, is, website, their,...
# 4       [reviewed, quite, a, bit, of, the, combo, play...
# 5       [i, also, began, having, the, incorrect, disc,...
# 6       [i, love, the, style, of, this, but, after, a,...
# 7       [i, cannot, scroll, through, a, dvd, menu, tha...
# 8       [exotic, tales, of, the, orient, from, the, is...
# 9       [firstly, i, enjoyed, the, format, and, tone, ...
# 10      [i, currently, live, in, europe, and, this, is...
# 11      [if, you, want, to, listen, to, el, duke, then...
# 12      [this, game, requires, quicktime, to, work, if...
# 13      [i, have, been, using, this, product, for, a, ...
# 14      [was, hoping, that, this, drive, would, run, o...
# 15      [first, of, all, the, company, took, my, money...
# 16      [this, is, an, awesome, game, almost, everyone...
# 17      [for, the, price, of, this, pc, game, is, well...
# 18      [y, este, libro, est, espl, ndido, lo, disfrut...
# 19      [this, is, an, excellent, album, with, some, g...
# 20      [i, have, read, this, book, with, much, expect...
# 21      [this, product, smells, when, you, open, the, ...
# 22      [the, magazine, was, in, very, good, condition...
# 23      [i, believe, i, will, be, very, happy, with, t...
# 24      [if, you, purchase, this, data, cable, you, ne...
# 25      [like, many, of, the, barbie, cd, roms, the, p...
# 26      [i, bought, this, item, to, connect, to, a, st...
# 27      [i, suppose, if, you, were, going, to, sit, in...
# 28      [ive, got, a, lamp, in, the, corner, of, my, r...
# 29      [very, disappointed, in, this, product, it, wo...
# ...                                                   ...
# 399970  [i, purchased, this, about, months, ago, and, ...
# 399971  [i, have, ordered, thousands, of, items, in, m...
# 399972  [my, parents, ordered, me, these, new, speaker...
# 399973  [i, like, to, listen, to, internet, radio, and...
# 399974  [i, made, a, small, long, warming, bench, for,...
# 399975  [neil, a, good, man, too, bad, he, did, not, l...
# 399976  [i, purchased, the, item, hoping, that, it, wo...
# 399977  [ferry, ferry, ferry, what, are, you, doing, i...
# 399978  [if, you, are, just, getting, started, or, hav...
# 399979  [my, children, ages, three, and, five, adore, ...
# 399980  [this, book, is, old, and, nigh, unto, useless...
# 399981  [while, this, book, seemed, very, appealing, f...
# 399982  [i, was, looking, for, a, book, that, would, b...
# 399983  [the, bulb, is, rated, for, up, to, hours, but...
# 399984  [buyers, be, warned, i, bought, an, ott, lite,...
# 399985  [this, item, is, all, i, expected, and, more, ...
# 399986  [as, a, teacher, and, collegiate, athletic, co...
# 399987  [my, keyboard, at, work, is, so, easy, to, use...
# 399988  [there, is, way, too, much, talking, and, deta...
# 399989  [buy, this, if, u, have, money, to, spend, on,...
# 399990  [i, am, so, happy, they, made, this, song, tog...
# 399991  [i, expected, more, about, how, to, create, lu...
# 399992  [this, is, not, what, i, expected, i, thought,...
# 399993  [this, is, not, music, no, matter, what, anyon...
# 399994  [this, is, a, fun, toy, and, my, and, year, ol...
# 399995  [we, bought, this, thomas, for, our, son, who,...
# 399996  [my, son, recieved, this, as, a, birthday, gif...
# 399997  [i, bought, this, toy, for, my, son, who, love...
# 399998  [this, is, a, compilation, of, a, wide, range,...
# 399999  [this, dvd, will, be, a, disappointment, if, y...
#
#                                                reviewText
# 0       My lovely Pat has one of the GREAT voices of h...
# 1       Despite the fact that I have only played a sma...
# 2       I bought this charger in Jul 2003 and it worke...
# 3       Check out Maha Energy's website. Their Powerex...
# 4       Reviewed quite a bit of the combo players and ...
# 5       I also began having the incorrect disc problem...
# 6       I love the style of this, but after a couple y...
# 7       I cannot scroll through a DVD menu that is set...
# 8       Exotic tales of the Orient from the 1930's. "D...
# 9       Firstly,I enjoyed the format and tone of the b...
# 10      I currently live in Europe, and this is the bo...
# 11      If you want to listen to El Duke , then it is ...
# 12      This game requires quicktime 5.0 to work...if ...
# 13      I have been using this product for a couple ye...
# 14      Was hoping that this drive would run off of bu...
# 15      First of all, the company took my money and se...
# 16      This is an AWESOME game! Almost everyone know ...
# 17      For the price of 7.99, this PC game is WELL wo...
# 18      Y ESTE LIBRO ESTÁ ESPLÉNDIDO !Lo disfrutas, lo...
# 19      This is an excellent album with some great fid...
# 20      I've read this book with much expectation, it ...
# 21      This product smells when you open the package ...
# 22      The magazine was in very good condition and ha...
# 23      I believe I will be very happy with the camcor...
# 24      If you purchase this data cable, you need to k...
# 25      Like many of the Barbie CD Roms, the playtime ...
# 26      i bought this item to connect to a strobe ligh...
# 27      I suppose if you were going to sit in the same...
# 28      ive got a lamp in the corner of my room behind...
# 29      Very disappointed in this product. It worked p...
# ...                                                   ...
# 399970  I purchased this about 4 months ago and it rea...
# 399971  I have ordered thousands of items in my lifeti...
# 399972  My parents ordered me these new speakers when ...
# 399973  I like to listen to internet radio and CDs whi...
# 399974  I made a small (24" long) warming bench for si...
# 399975  Neil, A Good Man. Too bad he didn't land or wa...
# 399976  I purchased the item hoping that it would fit ...
# 399977  Ferry, Ferry, Ferry. WHAT ARE YOU DOING!? I ca...
# 399978  If you are just getting started, or have been ...
# 399979  My children, ages three and five, adore Mr. Pu...
# 399980  ... This book is OLD and nigh unto useless unl...
# 399981  While this book seemed very appealing for some...
# 399982  I was looking for a book that would be a guide...
# 399983  The bulb is rated for up to 10,000 hours, but ...
# 399984  Buyers, be warned! I bought an Ott Lite a year...
# 399985  This item is all I expected and more wooooow n...
# 399986  As a teacher and collegiate athletic coach I f...
# 399987  My keyboard at work is so easy to use that I h...
# 399988  There is way too much talking and detailed exp...
# 399989  Buy this if u have money to spend on junk stuf...
# 399990  I'm so happy they made this song together beca...
# 399991  I expected more about how to create luck, mayb...
# 399992  This is not what I expected. I thought this wa...
# 399993  this is not music, no matter what anyone says....
# 399994  This is a fun toy and my 2 and 6 year olds lov...
# 399995  We bought this Thomas for our son who is a hug...
# 399996  My son recieved this as a birthday gift 2 mont...
# 399997  I bought this toy for my son who loves the "Th...
# 399998  This is a compilation of a wide range of Mitfo...
# 399999  This DVD will be a disappointment if you get i...
#
# [400000 rows x 5 columns]

# %%
max_sents = 10
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')) 

def addSents(loadDat = True, #stop_words=stop_words, test_data = test_data, train_data = train_data, 
             #yelp_zhang_train = yelp_zhang_train, yelp_zhang_test = yelp_zhang_test,
             #imdb_test = imdb_test, imdb_train = imdb_train, twitter_reviews = twitter_reviews,
             #yelp_reviews = yelp_reviews, sst_test = sst_test,
             amazon_zhang_test = amazon_zhang_test):
    
    if loadDat == True:
#         train_data_name = '../../train_data_cleaned_sents.pkl'
#         train_data = pd.read_pickle(train_data_name)
        
#         test_data_name = '../../train_data_cleaned_sents.pkl'
#         test_data = pd.read_pickle(test_data_name)
        
#         play_data_name = '../../play_data_cleaned_sents.pkl'
#         play_data = pd.read_pickle(play_data_name)
        
#         twitter_reviews_name = '../../twitter_reviews_cleaned_sents.pkl'
#         twitter_reviews = pd.read_pickle(twitter_reviews_name)
        
#         imdb_test_name = '../../imdb_test_cleaned_sents.pkl'
#         imdb_test = pd.read_pickle(imdb_test_name)
#         imdb_train_name = '../../imdb_train_cleaned_sents.pkl'
#         imdb_train = pd.read_pickle(imdb_train_name)
        
#         yelp_reviews_name = '../../yelp_reviews_cleaned_sents.pkl'
#         yelp_reviews = pd.read_pickle(yelp_reviews_name)
        
#         yelp_zhang_train_name = '../../yelp_zhang_pol_train_cleaned_sents.pkl'
#         yelp_zhang_train = pd.read_pickle(yelp_zhang_train_name)
#         yelp_zhang_test_name = '../../yelp_zhang_pol_test_cleaned_sents.pkl'
#         yelp_zhang_test = pd.read_pickle(yelp_zhang_test_name)
        
#         sst_test_name = '../../sst_test_sents.pkl'
#         sst_test = pd.read_pickle(sst_test_name)
        
        amazon_zhang_test_name = '../../amazon_zhang_test_pol_test_cleaned_sents.pkl'
        amazon_zhang_test = pd.read_pickle(amazon_zhang_test_name)
        
        print('Successfully opened pickled data')
        
        return train_data, test_data, play_data, twitter_reviews, imdb_test, imdb_train, yelp_reviews, yelp_zhang_train, yelp_zhang_test, sst_test
    
    else:

        #play_data = test_data[:10]

        def decontracted(phrase):
            phrase = re.sub(r"won\'t", "will not", phrase)
            phrase = re.sub(r"can\'t", "can not", phrase)
            phrase = re.sub(r"n\'t", " not", phrase)
            phrase = re.sub(r"\'re", " are", phrase)
            phrase = re.sub(r"\'s", " is", phrase)
            phrase = re.sub(r"\'d", " would", phrase)
            phrase = re.sub(r"\'ll", " will", phrase)
            phrase = re.sub(r"\'t", " not", phrase)
            phrase = re.sub(r"\'ve", " have", phrase)
            phrase = re.sub(r"\'m", " am", phrase)
            return phrase

        def prepReview(data):
            data_prep = str(data['reviewText'])
            data_prep = re.sub("[!?]", ".", data_prep)
            data_prep = re.sub("[^a-zA-Z'.]", " ", data_prep).lower()
            data_prep = re.sub("\.+", " . ", data_prep)
            data_prep = re.sub("\s+", " ", data_prep)
            data_prep = decontracted(data_prep)
            return data_prep

        #function to process review text and split into words
        def splitWords(data):
            
            words = []
            for word in prepReview(data).split():
                if word not in stop_words:
                    if (word != '.' )| (word != ' .'):
                        words.append(word)
            return words[:max_length]

        #function to process review text and split into sentences
        def splitSentences(data):
            interim = prepReview(data).split('.')
            return interim


#         #list of words from review into column
#         sentences = play_data.apply(splitWords, axis=1)
#         play_data.insert(loc = 11, column = 'sentenceWords_Stops', value = sentences)

#         sentences = train_data.apply(splitWords, axis=1)
#         train_data.insert(loc = 11,column = 'sentenceWords_Stops', value = sentences)

#         sentences = test_data.apply(splitWords, axis=1)
#         test_data.insert(loc = 11,column = 'sentenceWords_Stops', value = sentences)

#         #IMDB additions
#         sentences = imdb_test.apply(splitWords, axis=1)
#         imdb_test.insert(loc = 6,column = 'sentenceWords_Stops', value = sentences)
        
#         sentences = imdb_train.apply(splitWords, axis=1)
#         imdb_train.insert(loc = 6,column = 'sentenceWords_Stops', value = sentences)
        
#         sentences = twitter_reviews.apply(splitWords, axis=1)
#         twitter_reviews.insert(loc = 2,column = 'sentenceWords_Stops', value = sentences)
        
#         sentences = yelp_reviews.apply(splitWords, axis=1)
#         yelp_reviews.insert(loc = 2,column = 'sentenceWords_Stops', value = sentences)
        
#         sentences = yelp_zhang_train.apply(splitWords, axis=1)
#         yelp_zhang_train.insert(loc = 2,column = 'sentenceWords_Stops', value = sentences)
        
#         sentences = yelp_zhang_test.apply(splitWords, axis=1)
#         yelp_zhang_test.insert(loc = 2,column = 'sentenceWords_Stops', value = sentences)
        
        
        sentences = amazon_zhang_test.apply(splitWords, axis=1)
        amazon_zhang_test.insert(loc = 2,column = 'sentenceWords_Stops', value = sentences)
        
        print('Finished working through the words for each sentences\nOn to the sentences..')

#         #list of sentences from review into column
#         sentences_split = play_data.apply(splitSentences, axis=1)
#         play_data.insert(loc = 12, column = 'sentences_indiv', value = sentences_split)

#         sentences_split = train_data.apply(splitSentences, axis=1)
#         train_data.insert(loc = 12,column = 'sentences_indiv', value = sentences_split)

#         sentences_split = test_data.apply(splitSentences, axis=1)
#         test_data.insert(loc = 12,column = 'sentences_indiv', value = sentences_split)
        
#         #IMDB additions
#         sentences_split = imdb_test.apply(splitSentences, axis=1)
#         imdb_test.insert(loc = 7,column = 'sentences_indiv', value = sentences_split)

#         sentences_split = imdb_train.apply(splitSentences, axis=1)
#         imdb_train.insert(loc = 7,column = 'sentences_indiv', value = sentences_split)
        
#         sentences_split = twitter_reviews.apply(splitSentences, axis=1)
#         twitter_reviews.insert(loc = 3,column = 'sentences_indiv', value = sentences_split)
        
#         sentences_split = yelp_reviews.apply(splitSentences, axis=1)
#         yelp_reviews.insert(loc = 3,column = 'sentences_indiv', value = sentences_split)
        
#         sentences_split = yelp_zhang_train.apply(splitSentences, axis=1)
#         yelp_zhang_train.insert(loc = 2,column = 'sentences_indiv', value = sentences_split)
        
        sentences_split = amazon_zhang_test.apply(splitSentences, axis=1)
        amazon_zhang_test.insert(loc = 2,column = 'sentences_indiv', value = sentences_split)
        
        print('Finished sentences...\nNow moving on to pickling the data')

#         train_data_name = '../../train_data_cleaned_sents.pkl'
#         train_data.to_pickle(train_data_name)
        
#         test_data_name = '../../test_data_cleaned_sents.pkl'
#         test_data.to_pickle(test_data_name)
        
#         play_data_name = '../../play_data_cleaned_sents.pkl'
#         play_data.to_pickle(play_data_name)
        
#         twitter_reviews_name = '../../twitter_reviews_cleaned_sents.pkl'
#         twitter_reviews.to_pickle(twitter_reviews_name)
        
#         imdb_test_name = '../../imdb_test_cleaned_sents.pkl'
#         imdb_test.to_pickle(imdb_test_name)
#         imdb_train_name = '../../imdb_train_cleaned_sents.pkl'
#         imdb_train.to_pickle(imdb_train_name)
        
#         yelp_reviews_name = '../../yelp_reviews_cleaned_sents.pkl'
#         yelp_reviews.to_pickle(yelp_reviews_name)

#         yelp_zhang_train_name = '../../yelp_zhang_pol_train_cleaned_sents.pkl'
#         yelp_zhang_train.to_pickle(yelp_zhang_train_name)
#         yelp_zhang_test_name = '../../yelp_zhang_pol_test_cleaned_sents.pkl'
#         yelp_zhang_test.to_pickle(yelp_zhang_test_name)
        
#         sst_test_name = '../../sst_test_sents.pkl'
#         sst_test.to_pickle(sst_test_name)
        
        amazon_zhang_test_name = '../../amazon_zhang_test_pol_test_cleaned_sents.pkl'
        amazon_zhang_test.to_pickle(amazon_zhang_test_name)
        
        print('Finished pickling for future use.')
        
#         return train_data, test_data, play_data, twitter_reviews, imdb_test, imdb_train, yelp_reviews, yelp_zhang_train, yelp_zhang_test, sst_test
        
# train_data, test_data, play_data, twitter_reviews, imdb_test, imdb_train, yelp_reviews, yelp_zhang_train, yelp_zhang_test, sst_test = addSents(loadDat = True)

        return amazon_zhang_test
        
amazon_zhang_test = addSents(loadDat = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d6f7bf9a9f8a> in <module>()
#     193         return amazon_zhang_test
#     194
# --> 195 amazon_zhang_test = addSents(loadDat = True)
#
# <ipython-input-14-d6f7bf9a9f8a> in addSents(loadDat, amazon_zhang_test)
#      40
#      41         amazon_zhang_test_name = '../../amazon_zhang_test_pol_test_cleaned_sents.pkl'
# ---> 42         amazon_zhang_test = pd.read_pickle(yelp_zhang_test_name)
#      43
#      44         print('Successfully opened pickled data')
#
# NameError: name 'yelp_zhang_test_name' is not defined

# %%
amazon_zhang_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bf117e3fd7ec> in <module>()
# ----> 1 amazon_zhang_test
#
# NameError: name 'amazon_zhang_test' is not defined
