# %%
import pandas as pd
import numpy as np
pd.options.display.max_colwidth = 1000

# %%
zhang_yelp_reviews = pd.read_pickle('../../yelp_zhang_test_predictions.pkl')
yelp_reviews = pd.read_pickle('../../yelp_test_predictions.pkl')
twitter_sent140 = pd.read_pickle('../../twitter_sent140_test_predictions.pkl')
imdb_reviews = pd.read_pickle('../../imdb_test_predictions.pkl')

# %%
imdb_reviews.head()
# Out:
#    Unnamed: 0  X  type                                         reviewText  \
# 0           1  0  test  Once again Mr. Costner has dragged out a movie...
# 1           2  1  test  This is an example of why the majority of acti...
# 2           3  2  test  First of all I hate those moronic rappers, who...
# 3           4  3  test  Not even the Beatles could write songs everyon...
# 4           5  4  test  Brass pictures (movies is not a fitting word f...
#
#   label  sentiment                                sentenceWords_Stops  \
# 0   neg          0  [mr, ., costner, dragged, movie, far, longer, ...
# 1   neg          0  [example, majority, action, films, ., generic,...
# 2   neg          0  [first, hate, moronic, rappers, could'nt, act,...
# 3   neg          0  [even, beatles, could, write, songs, everyone,...
# 4   neg          0  [brass, pictures, movies, fitting, word, reall...
#
#                                      sentences_indiv  \
# ...

# %%
imdb_reviews['w2V_diff'] = imdb_reviews['CNN_w2V'] - imdb_reviews['CNN_w2V_USE']
imdb_reviews.sort_values(by=['w2V_diff'])
# Out:
#        Unnamed: 0      X  type  \
# 23589       23590  23589  test
# 5395         5396   5395  test
# 20301       20302  20301  test
# 12805       12806  12805  test
# 16686       16687  16686  test
# 19135       19136  19135  test
# 19629       19630  19629  test
# 23507       23508  23507  test
# 18027       18028  18027  test
# 9346         9347   9346  test
# 4538         4539   4538  test
# 188           189    188  test
# 14717       14718  14717  test
# 9400         9401   9400  test
# 16949       16950  16949  test
# 23824       23825  23824  test
# 20290       20291  20290  test
# 18260       18261  18260  test
# 15926       15927  15926  test
# 13236       13237  13236  test
# 22906       22907  22906  test
# 22012       22013  22012  test
# 166           167    166  test
# 24366       24367  24366  test
# 16687       16688  16687  test
# 19819       19820  19819  test
# 1548         1549   1548  test
# 23313       23314  23313  test
# 13611       13612  13611  test
# ...
